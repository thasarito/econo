# %%
# %matplotlib inline
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('float_format', '{:f}'.format)

def plotPlayer(id):
    player = id
    fig = plt.figure(figsize=(10, 6))
    ax = fig.gca()
    df[df['id'] == player][['wrating', 'age']].set_index('age').sort_index().plot(ax=ax)
    df[df['id'] == player][['rating', 'age']].set_index('age').sort_index().plot(ax=ax)
    return (df[df['id'] == player][['wrating', 'tour', 'age', 'team', 'start']].set_index('age').sort_index())

# %%
def load_csv(system):
    df = pd.read_csv(system + '.csv', encoding="utf-8")
    df.start = pd.to_datetime(df.start, format='%d/%m/%Y')
    df.end = pd.to_datetime(df.end, format='%d/%m/%Y')
    dob = pd.read_csv('dob.csv', encoding="utf-8")
    dob.id = dob.id.str.replace(r'\W+', '').str.lower()
    return df, dob

def cumulativeRating(diff, ratingName, df):
    cumsums = df[['id', 'start', diff]].groupby(['id', 'start']).sum().groupby(level=0).cumsum()
    df = df.set_index(['id', 'start'])
    df['cumur'] = cumsums
    df = df.reset_index()
    init = df[df['startglicko2rating'].notnull()].sort_values('start')[['startglicko2rating', 'id']].groupby('id').first().reset_index().rename(columns={'startglicko2rating': 'init'})
    df = pd.merge(df, init, how='left', on='id')
    df[ratingName] = df.cumur + df.init
    return df

def teamRating(rating, df):
    teameff = df.merge((df.groupby(['team', 'start']).mean()[rating] * 5).reset_index().rename(columns={rating: 'teamrating'}), on=['team', 'start'])
    teameff.teamrating = (teameff.teamrating - teameff[rating]) / 4
    return teameff

def experience(df):
    dfid2 = pd.DataFrame()
    for player in df.id.unique():
        dfid = pd.DataFrame(df[df['id'] == player].sort_values('start').tour.unique()).reset_index().rename(columns={'index': 'exp', 0: 'tour'})
        dfid['id'] = player
        dfid2 = pd.concat([dfid2, dfid])
    return pd.merge(df, dfid2, how='left', on=['id', 'tour'])
    
def dobMerge(df, dob):
    dob.id = dob.id.str.replace(r'\W+', '').str.lower()
    df = df.merge(dob, how='left', on=['id'])
    df.dob = pd.to_datetime(df.dob, format='%Y/%m/%d')
    df['age'] = (df.start - df.dob) / pd.Timedelta(days=365.25)
    return df

# %%
df, dob = load_csv('glickoandprize')
df['diffr'] = df.endglicko2rating - df.startglicko2rating
df = cumulativeRating('diffr', 'normalRating', df)
df = teamRating('normalRating', df)
df = experience(df)
df.drop_duplicates(subset=['id', 'start'], inplace=True)

# %%
df, dob = load_csv('glickoandprize')
df['diffr'] = df.endglicko2rating - df.startglicko2rating
df = cumulativeRating('diffr', 'normalRating', df)
df = teamRating('normalRating', df)
df = experience(df)
df.drop_duplicates(subset=['id', 'start'], inplace=True)
df.dropna(inplace=True)
df = dobMerge(df, dob)
df.dropna(inplace=True)
df = df[(df.prizepool != 'Nan')]
df.prizepool = pd.to_numeric(df.prizepool)
df.prizeusd = pd.to_numeric(df.prizeusd.str.replace(r'\D', ''))

# %%
df['season'] = 'ti3'
df.loc[(df.start > pd.to_datetime('2013-08-02')) & (df.start <= pd.to_datetime('2014-07-08')), 'season'] = 'ti4'
df.loc[(df.start > pd.to_datetime('2014-07-08')) & (df.start <= pd.to_datetime('2015-07-27')), 'season'] = 'ti5'
df.loc[(df.start > pd.to_datetime('2015-07-27')) & (df.start <= pd.to_datetime('2016-08-02')), 'season'] = 'ti6'
df.loc[(df.start > pd.to_datetime('2016-08-02')) & (df.start <= pd.to_datetime('2017-08-02')), 'season'] = 'ti7'

# %%
df['tiprize'] = np.log(int(df[df['tour'] == 'The International 2013'].prizepool.iloc[0]))
df.loc[(df.season == 'ti4'), 'tiprize'] = np.log(int(df[df['tour'] == 'The International 2014'].prizepool.iloc[0]))
df.loc[(df.season == 'ti5'), 'tiprize'] = np.log(int(df[df['tour'] == 'The International 2015'].prizepool.iloc[0]))
df.loc[(df.season == 'ti6'), 'tiprize'] = np.log(int(df[df['tour'] == 'The International 2016'].prizepool.iloc[0]))
df.loc[(df.season == 'ti7'), 'tiprize'] = np.log(int(df[df['tour'] == 'The International 2017'].prizepool.iloc[0]))

df['wdiffr'] = (df.prizepool.apply(np.log) / df.tiprize) * df.diffr

#cumulative sum of wdiffr
cumsums = df[['id', 'start', 'wdiffr']].groupby(['id', 'start']).sum().groupby(level=0).cumsum()
df = df.set_index(['id', 'start'])
df['cumuwr'] = cumsums
df = df.reset_index()
df['perf'] = df.cumuwr + df.init

# %%
nt = df.groupby('id').size().reset_index()
df = df[df['id'].isin(nt[nt[0] >= 10].id.unique())]

# %%
df.head()
# Out:
#        id      start  Unnamed: 0           team  pos  \
# 0   mushi 2012-09-08           0  orangeesports    1
# 1    kyxy 2012-09-08           1  orangeesports    2
# 2  xtinct 2012-09-08           3  orangeesports    4
# 4    fear 2012-09-10          40   evilgeniuses    1
# 5    jeyo 2012-09-10          41   evilgeniuses    2
#
#                               tour    prizepool place  prizeusd  \
# 0      WCG Asian Championship 2012  6000.000000    1       3000
# 1      WCG Asian Championship 2012  6000.000000    1       3000
# 2      WCG Asian Championship 2012  6000.000000    1       3000
# 4  RaidCall Dota 2 League Season 1 10000.000000    2       3000
# 5  RaidCall Dota 2 League Season 1 10000.000000    2       3000
#
#    startglicko2mu     ...      exp            cog                  name  \
# 0     1609.568030     ...        0       Malaysia         Chai Yee Fung
# 1     1609.568030     ...        0       Malaysia         Lee Kong Yang
# 2     1609.568030     ...        0       Malaysia  Joel Chan Zhan Leong
# 4     1739.804399     ...        0  United States        Clinton Loomis
# 5     1739.804399     ...        0         Canada           Jio Madayag
#
#          dob       age  season   tiprize    wdiffr    cumuwr        perf
# 0 1990-11-27 21.782341     ti3 14.871348 -1.214596 -1.214596 1445.816755
# 1 1991-05-26 21.289528     ti3 14.871348 -1.214596 -1.214596 1445.816755
# 2 1988-10-16 23.895962     ti3 14.871348 -1.214596 -1.214596 1445.816755
# 4 1988-02-19 24.558522     ti3 14.871348 37.003142 37.003142 1631.179011
# 5 1993-04-19 19.394935     ti3 14.871348 37.003142 37.003142 1631.179011
#
# [5 rows x 31 columns]

# %%
from scipy import stats
main = df.groupby('id').agg({'pos': lambda x:stats.mode(x)[0]}).reset_index()
main = main.rename(index=str, columns={'pos': 'main'})
df = df.merge(main, how='left', on=['id'])

# %%
ent = pd.DataFrame(df.id.unique()).reset_index().rename(columns={'index': 'entity', 0: 'id'})
df = ent.merge(df, on='id', how='left')

# %%
pd.set_option('float_format', '{:f}'.format)

# %%
def panelOLSResult(df, Y, X):
    from linearmodels import PanelOLS 
    panel_data = df.set_index(['entity', 'start']).sort_index()
    panel_data['agesq'] = panel_data.age ** 2
    panel_data['const'] = 1
    panel_data['lexp'] = (panel_data['exp'] + 1).apply(np.log)
    Y = panel_data[Y]
    X = panel_data[X]
    mod = PanelOLS(Y, X, entity_effects=True)
    return mod.fit()

def feResult(res):
    fe = res.estimated_effects.reset_index().drop_duplicates().drop_duplicates(subset=['entity']).drop('time', 1)
    return ent.merge(fe, on='entity').sort_values('estimated_effects', ascending=False)

# %% [markdown]
# ### Age and experience

# %%
from linearmodels import PanelOLS 
panel_data = df[['entity', 'start', 'perf', 'age', 'exp', 'pos']].set_index(['entity', 'start']).sort_index()
panel_data['agesq'] = panel_data.age ** 2
panel_data['const'] = 1
panel_data['lexp'] = (panel_data['exp'] + 1).apply(np.log)

# %%
len(df.entity.unique())
# Out:
# 164

# %%
df.tail()
# Out:
#       entity     id      start  Unnamed: 0        team  pos  \
# 4856     163  khezu 2017-05-25       11947  teamsecret    3
# 4857     163  khezu 2017-06-04       12067  teamsecret    3
# 4858     163  khezu 2017-06-14       12117  teamsecret    3
# 4859     163  khezu 2017-07-21       12267  teamsecret    3
# 4860     163  khezu 2017-08-02       12342  teamsecret    3
#
#                         tour       prizepool  place  prizeusd  ...       cog  \
# 4856      The Manila Masters   250000.000000   7-8       5000  ...   Germany
# 4857          EPICENTER 2017   500000.000000   3-4      40000  ...   Germany
# 4858           DOTA Summit 7   100000.000000     2      22500  ...   Germany
# 4859    DreamLeague Season 7   175000.000000     3      30000  ...   Germany
# 4860  The International 2017 24787916.000000  9-12     370319  ...   Germany
#
#                  name        dob       age  season   tiprize     wdiffr  \
# 4856  Maurice Gutmann 1995-04-27 22.078029     ti7 17.025867  15.497141
# 4857  Maurice Gutmann 1995-04-27 22.105407     ti7 17.025867  13.397750
# 4858  Maurice Gutmann 1995-04-27 22.132786     ti7 17.025867  -3.543186
# 4859  Maurice Gutmann 1995-04-27 22.234086     ti7 17.025867 -10.692056
# 4860  Maurice Gutmann 1995-04-27 22.266940     ti7 17.025867  -2.891659
#
#         cumuwr        perf  main
# 4856 41.761507 1729.831043     3
# 4857 55.159257 1743.228793     3
# 4858 51.616072 1739.685607     3
# 4859 40.924015 1728.993551     3
# 4860 38.032356 1726.101891     3
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#            entity   Unnamed: 0         pos       prizepool  \
# count 4861.000000  4861.000000 4861.000000     4861.000000
# mean    67.187821  6918.633203    2.996091  1342571.963859
# std     43.980297  3386.208016    1.415299  4296199.481134
# min      0.000000     0.000000    1.000000     4410.000000
# 25%     29.000000  4248.000000    2.000000    39000.000000
# 50%     62.000000  7312.000000    3.000000   100000.000000
# 75%    102.000000  9622.000000    4.000000   277668.000000
# max    163.000000 12374.000000    5.000000 24787916.000000
#
#                  prizeusd  startglicko2mu  startglicko2phi  \
# count         4861.000000     4861.000000      4861.000000
# mean     264136105.668792     1841.128250        42.634076
# std     3622600182.947815       97.213157         6.576886
# min              0.000000     1542.725781        28.869240
# 25%           1500.000000     1778.144576        38.363352
# 50%          14000.000000     1847.199041        41.489108
# 75%          96860.000000     1913.222326        44.995443
# max   102512933715.000000     2070.341655        69.914737
#
#        startglicko2rating  endglicko2mu  endglicko2phi     ...      \
# count         4861.000000   4861.000000    4861.000000     ...
# mean          1734.543059   1845.487274      41.275249     ...
# std            102.479247     95.447060       5.895585     ...
# min           1377.868237   1514.769232      27.318820     ...
# 25%           1663.140303   1780.646087      37.368550     ...
# 50%           1742.696820   1849.448321      40.319949     ...
# 75%           1811.580851   1915.028650      43.742622     ...
# max           1952.785682   2089.277451      68.869853     ...
#
#              init  normalRating  teamrating         exp         age  \
# count 4861.000000   4861.000000 4861.000000 4861.000000 4861.000000
# mean  1598.728616   1869.730939 1856.011608   26.041761   22.639532
# std     94.677296    252.564205  186.150147   17.359077    2.498968
# min   1377.868237   1120.965747 1321.284974    0.000000   15.739904
# 25%   1540.350904   1698.604900 1721.643107   12.000000   20.941821
# 50%   1603.306830   1841.067619 1847.128391   22.000000   22.696783
# 75%   1645.784093   2005.501781 1983.505873   37.000000   24.399726
# max   1898.778787   2698.966417 2411.544440   83.000000   29.333333
#
#           tiprize      wdiffr      cumuwr        perf        main
# count 4861.000000 4861.000000 4861.000000 4861.000000 4861.000000
# mean    16.463026    5.124528  174.901909 1773.630525    3.059247
# std      0.683499   25.210886  176.125550  171.782185    1.443371
# min     14.871348 -181.977433 -268.931932 1334.374897    1.000000
# 25%     16.206471   -5.364576   37.988052 1654.939317    2.000000
# 50%     16.729469   -1.967027  148.379382 1752.318285    3.000000
# 75%     16.849042   12.563774  286.714991 1878.260351    4.000000
# max     17.025867  153.087427  653.655179 2275.313145    5.000000
#
# [8 rows x 23 columns]

# %%
panel_data.describe()
# Out:
#              perf         age         exp         pos       agesq       const  \
# count 4861.000000 4861.000000 4861.000000 4861.000000 4861.000000 4861.000000
# mean  1773.630525   22.639532   26.041761    2.996091  518.791967    1.000000
# std    171.782185    2.498968   17.359077    1.415299  112.871091    0.000000
# min   1334.374897   15.739904    0.000000    1.000000  247.744583    1.000000
# 25%   1654.939317   20.941821   12.000000    2.000000  438.559853    1.000000
# 50%   1752.318285   22.696783   22.000000    3.000000  515.143960    1.000000
# 75%   1878.260351   24.399726   37.000000    4.000000  595.346639    1.000000
# max   2275.313145   29.333333   83.000000    5.000000  860.444444    1.000000
#
#              lexp
# count 4861.000000
# mean     3.041507
# std      0.798491
# min      0.000000
# 25%      2.564949
# 50%      3.135494
# 75%      3.637586
# max      4.430817

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 15))
for i, ax in enumerate(axs.reshape(-1)):
    if i == 5:
        of = df
    else:
        of = df[df.main == i+1]
    for index, data in of.groupby('entity'):
        ax.plot(data.age, data.perf)
    ax.set_xlim(15, 30)
    ax.set_ylim(1300, 2300)
    if i == 5:
        ax.set_title("plot for all " + str(len(of.entity.unique())) + " players")
    else:
        ax.set_title("plot for position " + str(i+1) + " from " + str(len(of.entity.unique())) + " players")
plt.show()

# %%
from linearmodels import PanelOLS 
carry = df[df.main == 1]
nt = carry.groupby('id').size().reset_index()
carry = carry[carry['id'].isin(nt[nt[0] >= 10].id.unique())]
carry = carry[['entity', 'start', 'perf', 'age', 'exp', 'pos']].set_index(['entity', 'start']).sort_index()
carry['agesq'] = carry.age ** 2
carry['const'] = 1
carry['lexp'] = (carry['exp'] + 1).apply(np.log)

# %%
Y = carry['perf']
X = carry[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.3460
# Estimator:                   PanelOLS   R-squared (Between):              0.3558
# No. Observations:                 954   R-squared (Within):               0.3460
# Date:                Sat, May 05 2018   R-squared (Overall):              0.3975
# Time:                        14:36:13   Log-likelihood                   -5580.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      162.60
# Entities:                          29   P-value                           0.0000
# Avg Obs:                       32.897   Distribution:                   F(3,922)
# Min Obs:                       11.000
# Max Obs:                       66.000   F-statistic (robust):             162.60
#                                         P-value                           0.0000
# Time periods:                     205   Distribution:                   F(3,922)
# Avg Obs:                       4.6537
# Min Obs:                       1.0000
# Max Obs:                       14.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            241.49     27.218     8.8723     0.0000      188.07      294.91
# agesq         -4.6778     0.5563    -8.4086     0.0000     -5.7695     -3.5860
# lexp           41.436     7.8641     5.2691     0.0000      26.003      56.870
# ==============================================================================
#
# F-test for Poolability: 86.779
# P-value: 0.0000
# Distribution: F(28,922)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
from linearmodels import PanelOLS 
carry = df[df.pos == 2]
nt = carry.groupby('id').size().reset_index()
carry = carry[carry['id'].isin(nt[nt[0] >= 10].id.unique())]
carry = carry[['entity', 'start', 'perf', 'age', 'exp', 'pos']].set_index(['entity', 'start']).sort_index()
carry['agesq'] = carry.age ** 2
carry['const'] = 1
carry['lexp'] = (carry['exp'] + 1).apply(np.log)

# %%
Y = carry['perf']
X = carry[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.3341
# Estimator:                   PanelOLS   R-squared (Between):              0.9910
# No. Observations:                 847   R-squared (Within):               0.3341
# Date:                Sat, May 05 2018   R-squared (Overall):              0.9900
# Time:                        14:36:13   Log-likelihood                   -4893.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      135.48
# Entities:                          34   P-value                           0.0000
# Avg Obs:                       24.912   Distribution:                   F(3,810)
# Min Obs:                      10.0000
# Max Obs:                       66.000   F-statistic (robust):             135.48
#                                         P-value                           0.0000
# Time periods:                     203   Distribution:                   F(3,810)
# Avg Obs:                       4.1724
# Min Obs:                       1.0000
# Max Obs:                       15.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            129.24     40.837     3.1647     0.0016      49.079      209.40
# agesq         -2.3040     0.8548    -2.6952     0.0072     -3.9820     -0.6260
# lexp           49.245     8.2782     5.9487     0.0000      32.995      65.494
# ==============================================================================
#
# F-test for Poolability: 47.482
# P-value: 0.0000
# Distribution: F(33,810)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
from linearmodels import PanelOLS 
carry = df[df.pos == 3]
nt = carry.groupby('id').size().reset_index()
carry = carry[carry['id'].isin(nt[nt[0] >= 10].id.unique())]
carry = carry[['entity', 'start', 'perf', 'age', 'exp', 'pos']].set_index(['entity', 'start']).sort_index()
carry['agesq'] = carry.age ** 2
carry['const'] = 1
carry['lexp'] = (carry['exp'] + 1).apply(np.log)

# %%
Y = carry['perf']
X = carry[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.9933
# Estimator:                   PanelOLS   R-squared (Between):              0.9954
# No. Observations:                 832   R-squared (Within):               0.2859
# Date:                Sat, May 05 2018   R-squared (Overall):              0.9933
# Time:                        14:41:52   Log-likelihood                   -5340.5
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   4.097e+04
# Entities:                          39   P-value                           0.0000
# Avg Obs:                       21.333   Distribution:                   F(3,829)
# Min Obs:                      10.0000
# Max Obs:                       53.000   F-statistic (robust):          4.097e+04
#                                         P-value                           0.0000
# Time periods:                     202   Distribution:                   F(3,829)
# Avg Obs:                       4.1188
# Min Obs:                       1.0000
# Max Obs:                       14.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            132.36     2.4189     54.718     0.0000      127.61      137.10
# agesq         -3.0397     0.0944    -32.217     0.0000     -3.2249     -2.8545
# lexp           122.80     7.3148     16.788     0.0000      108.45      137.16
# ==============================================================================
#
#
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
from linearmodels import PanelOLS 
carry = df[df.pos == 4]
nt = carry.groupby('id').size().reset_index()
carry = carry[carry['id'].isin(nt[nt[0] >= 10].id.unique())]
carry = carry[['entity', 'start', 'perf', 'age', 'exp', 'pos']].set_index(['entity', 'start']).sort_index()
carry['agesq'] = carry.age ** 2
carry['const'] = 1
carry['lexp'] = (carry['exp'] + 1).apply(np.log)

# %%
Y = carry['perf']
X = carry[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.9917
# Estimator:                   PanelOLS   R-squared (Between):              0.9928
# No. Observations:                 794   R-squared (Within):               0.2273
# Date:                Sat, May 05 2018   R-squared (Overall):              0.9917
# Time:                        14:42:46   Log-likelihood                   -5164.0
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                   3.143e+04
# Entities:                          40   P-value                           0.0000
# Avg Obs:                       19.850   Distribution:                   F(3,791)
# Min Obs:                      10.0000
# Max Obs:                       52.000   F-statistic (robust):          3.143e+04
#                                         P-value                           0.0000
# Time periods:                     199   Distribution:                   F(3,791)
# Avg Obs:                       3.9899
# Min Obs:                       1.0000
# Max Obs:                       13.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            151.29     2.6031     58.118     0.0000      146.18      156.40
# agesq         -3.9102     0.0988    -39.581     0.0000     -4.1041     -3.7163
# lexp           118.84     8.8244     13.467     0.0000      101.51      136.16
# ==============================================================================
#
#
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
from linearmodels import PanelOLS 
carry = df[df.pos == 5]
nt = carry.groupby('id').size().reset_index()
carry = carry[carry['id'].isin(nt[nt[0] >= 10].id.unique())]
carry = carry[['entity', 'start', 'perf', 'age', 'exp', 'pos']].set_index(['entity', 'start']).sort_index()
carry['agesq'] = carry.age ** 2
carry['const'] = 1
carry['lexp'] = (carry['exp'] + 1).apply(np.log)

# %%
Y = carry['perf']
X = carry[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.3189
# Estimator:                   PanelOLS   R-squared (Between):              0.9938
# No. Observations:                 832   R-squared (Within):               0.3189
# Date:                Sat, May 05 2018   R-squared (Overall):              0.9903
# Time:                        14:36:15   Log-likelihood                   -4828.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      123.31
# Entities:                          39   P-value                           0.0000
# Avg Obs:                       21.333   Distribution:                   F(3,790)
# Min Obs:                      10.0000
# Max Obs:                       53.000   F-statistic (robust):             123.31
#                                         P-value                           0.0000
# Time periods:                     202   Distribution:                   F(3,790)
# Avg Obs:                       4.1188
# Min Obs:                       1.0000
# Max Obs:                       14.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            139.96     34.895     4.0107     0.0001      71.458      208.46
# agesq         -3.4890     0.7226    -4.8283     0.0000     -4.9074     -2.0705
# lexp           114.98     9.0633     12.686     0.0000      97.184      132.77
# ==============================================================================
#
# F-test for Poolability: 50.264
# P-value: 0.0000
# Distribution: F(38,790)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 15))
for i, ax in enumerate(axs.reshape(-1)):
    if i == 5:
        of = df
    else:
        of = df[df.main == i+1]
    for index, data in of.groupby('entity'):
        ax.plot(data.age, data.perf)
    ax.set_xlim(15, 30)
    ax.set_ylim(1300, 2300)
    if i == 5:
        ax.set_title("plot for all " + str(len(of.entity.unique())) + " players")
    else:
        ax.set_title("plot for position " + str(i+1) + " from " + str(len(of.entity.unique())) + " players")
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5))
of = df[df.main <= 3]
for index, data in of.groupby('entity'):
    axs[0].plot(data.age, data.perf)
    axs[0].set_xlim(15, 30)
    axs[0].set_ylim(1300, 2300)
    axs[0].set_title(str(len(of.entity.unique())) + " Core players' plot")
ef = df[df.main >= 4]
for index, data in ef.groupby('entity'):
    axs[1].plot(data.age, data.perf)
    axs[1].set_xlim(15, 30)
    axs[1].set_ylim(1300, 2300)
    axs[1].set_title(str(len(ef.entity.unique())) + " Support players' plot")    
plt.show()

# %%
df.head()
# Out:
#    entity     id      start  Unnamed: 0           team  pos  \
# 0       0  mushi 2012-09-08           0  orangeesports    1
# 1       0  mushi 2012-10-22         216  orangeesports    2
# 2       0  mushi 2012-11-29         671  orangeesports    2
# 3       0  mushi 2014-05-24        4891             dk    2
# 4       0  mushi 2015-01-05        6679       lvgaming    5
#
#                             tour    prizepool place  prizeusd  ...        cog  \
# 0    WCG Asian Championship 2012  6000.000000    1       3000  ...   Malaysia
# 1  G-1 Champions League Season 4 52879.200000    3       8012  ...   Malaysia
# 2         World Cyber Games 2012 33000.000000     4         0  ...   Malaysia
# 3      MarsTV Dota 2 League 2014 24046.500000  3-4     160310  ...   Malaysia
# 4         Dota 2 League Season 5 58397.000000    1      26679  ...   Malaysia
#
#             name        dob       age  season   tiprize    wdiffr    cumuwr  \
# 0  Chai Yee Fung 1990-11-27 21.782341     ti3 14.871348 -1.214596 -1.214596
# 1  Chai Yee Fung 1990-11-27 21.902806     ti3 14.871348 47.650947 46.436351
# 2  Chai Yee Fung 1990-11-27 22.006845     ti3 14.871348 -1.442597 44.993754
# 3  Chai Yee Fung 1990-11-27 23.488022     ti4 16.206471  7.779183 52.772936
# 4  Chai Yee Fung 1990-11-27 24.106776     ti5 16.729469 -1.633441 51.139496
#
#          perf  main
# 0 1445.816755     2
# 1 1493.467703     2
# 2 1492.025105     2
# 3 1499.804288     2
# 4 1498.170847     2
#
# [5 rows x 33 columns]

# %%
df[['entity', 'start', 'main', 'age', 'exp', 'perf']].to_csv("statapos.csv", encoding="utf-8")
