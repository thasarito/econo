# %%
# %matplotlib inline
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('float_format', '{:f}'.format)

def plotPlayer(id):
    player = id
    fig = plt.figure(figsize=(10, 6))
    ax = fig.gca()
    df[df['id'] == player][['wrating', 'age']].set_index('age').sort_index().plot(ax=ax)
    df[df['id'] == player][['rating', 'age']].set_index('age').sort_index().plot(ax=ax)
    return (df[df['id'] == player][['wrating', 'tour', 'age', 'team', 'start']].set_index('age').sort_index())

# %%
def load_csv(system):
    df = pd.read_csv(system + '.csv', encoding="utf-8")
    df.start = pd.to_datetime(df.start, format='%d/%m/%Y')
    df.end = pd.to_datetime(df.end, format='%d/%m/%Y')
    dob = pd.read_csv('dob.csv', encoding="utf-8")
    dob.id = dob.id.str.replace(r'\W+', '').str.lower()
    return df, dob

def cumulativeRating(diff, ratingName, df):
    cumsums = df[['id', 'start', diff]].groupby(['id', 'start']).sum().groupby(level=0).cumsum()
    df = df.set_index(['id', 'start'])
    df['cumur'] = cumsums
    df = df.reset_index()
    init = df[df['startglicko2rating'].notnull()].sort_values('start')[['startglicko2rating', 'id']].groupby('id').first().reset_index().rename(columns={'startglicko2rating': 'init'})
    df = pd.merge(df, init, how='left', on='id')
    df[ratingName] = df.cumur + df.init
    return df

def teamRating(rating, df):
    teameff = df.merge((df.groupby(['team', 'start']).mean()[rating] * 5).reset_index().rename(columns={rating: 'teamrating'}), on=['team', 'start'])
    teameff.teamrating = (teameff.teamrating - teameff[rating]) / 4
    return teameff

def experience(df):
    dfid2 = pd.DataFrame()
    for player in df.id.unique():
        dfid = pd.DataFrame(df[df['id'] == player].sort_values('start').tour.unique()).reset_index().rename(columns={'index': 'exp', 0: 'tour'})
        dfid['id'] = player
        dfid2 = pd.concat([dfid2, dfid])
    return pd.merge(df, dfid2, how='left', on=['id', 'tour'])
    
def dobMerge(df, dob):
    dob.id = dob.id.str.replace(r'\W+', '').str.lower()
    df = df.merge(dob, how='left', on=['id'])
    df.dob = pd.to_datetime(df.dob, format='%Y/%m/%d')
    df['age'] = (df.start - df.dob) / pd.Timedelta(days=365.25)
    return df

# %%
df, dob = load_csv('glickoandprize')
df['diffr'] = df.endglicko2rating - df.startglicko2rating
df = cumulativeRating('diffr', 'normalRating', df)
df = teamRating('normalRating', df)
df = experience(df)
df.drop_duplicates(subset=['id', 'start'], inplace=True)

# %%
df, dob = load_csv('glickoandprize')
df['diffr'] = df.endglicko2rating - df.startglicko2rating
df = cumulativeRating('diffr', 'normalRating', df)
df = teamRating('normalRating', df)
df = experience(df)
df.drop_duplicates(subset=['id', 'start'], inplace=True)
df.dropna(inplace=True)
df = dobMerge(df, dob)
df.dropna(inplace=True)
df = df[(df.prizepool != 'Nan')]
df.prizepool = pd.to_numeric(df.prizepool)
df.prizeusd = pd.to_numeric(df.prizeusd.str.replace(r'\D', ''))

# %%
df['season'] = 'ti3'
df.loc[(df.start > pd.to_datetime('2013-08-02')) & (df.start <= pd.to_datetime('2014-07-08')), 'season'] = 'ti4'
df.loc[(df.start > pd.to_datetime('2014-07-08')) & (df.start <= pd.to_datetime('2015-07-27')), 'season'] = 'ti5'
df.loc[(df.start > pd.to_datetime('2015-07-27')) & (df.start <= pd.to_datetime('2016-08-02')), 'season'] = 'ti6'
df.loc[(df.start > pd.to_datetime('2016-08-02')) & (df.start <= pd.to_datetime('2017-08-02')), 'season'] = 'ti7'

# %%
df['tiprize'] = np.log(int(df[df['tour'] == 'The International 2013'].prizepool.iloc[0]))
df.loc[(df.season == 'ti4'), 'tiprize'] = np.log(int(df[df['tour'] == 'The International 2014'].prizepool.iloc[0]))
df.loc[(df.season == 'ti5'), 'tiprize'] = np.log(int(df[df['tour'] == 'The International 2015'].prizepool.iloc[0]))
df.loc[(df.season == 'ti6'), 'tiprize'] = np.log(int(df[df['tour'] == 'The International 2016'].prizepool.iloc[0]))
df.loc[(df.season == 'ti7'), 'tiprize'] = np.log(int(df[df['tour'] == 'The International 2017'].prizepool.iloc[0]))

df['wdiffr'] = (df.prizepool.apply(np.log) / df.tiprize) * df.diffr

#cumulative sum of wdiffr
cumsums = df[['id', 'start', 'wdiffr']].groupby(['id', 'start']).sum().groupby(level=0).cumsum()
df = df.set_index(['id', 'start'])
df['cumuwr'] = cumsums
df = df.reset_index()
df['perf'] = df.cumuwr + df.init

# %%
ent = pd.DataFrame(df.id.unique()).reset_index().rename(columns={'index': 'entity', 0: 'id'})
df = ent.merge(df, on='id', how='left')

# %%
pd.set_option('float_format', '{:f}'.format)

# %%
df.head()
# Out:
#    entity     id      start  Unnamed: 0           team  pos  \
# 0       0  mushi 2012-09-08           0  orangeesports    1
# 1       0  mushi 2012-10-22         216  orangeesports    2
# 2       0  mushi 2012-11-29         671  orangeesports    2
# 3       0  mushi 2014-05-24        4891             dk    2
# 4       0  mushi 2015-01-05        6679       lvgaming    5
#
#                             tour    prizepool place  prizeusd     ...      \
# 0    WCG Asian Championship 2012  6000.000000    1       3000     ...
# 1  G-1 Champions League Season 4 52879.200000    3       8012     ...
# 2         World Cyber Games 2012 33000.000000     4         0     ...
# 3      MarsTV Dota 2 League 2014 24046.500000  3-4     160310     ...
# 4         Dota 2 League Season 5 58397.000000    1      26679     ...
#
#    exp       cog           name        dob       age  season   tiprize  \
# 0    0  Malaysia  Chai Yee Fung 1990-11-27 21.782341     ti3 14.871348
# 1    1  Malaysia  Chai Yee Fung 1990-11-27 21.902806     ti3 14.871348
# 2    2  Malaysia  Chai Yee Fung 1990-11-27 22.006845     ti3 14.871348
# 3   21  Malaysia  Chai Yee Fung 1990-11-27 23.488022     ti4 16.206471
# 4   29  Malaysia  Chai Yee Fung 1990-11-27 24.106776     ti5 16.729469
#
#      wdiffr    cumuwr        perf
# 0 -1.214596 -1.214596 1445.816755
# 1 47.650947 46.436351 1493.467703
# 2 -1.442597 44.993754 1492.025105
# 3  7.779183 52.772936 1499.804288
# 4 -1.633441 51.139496 1498.170847
#
# [5 rows x 32 columns]

# %%
nt = df.groupby('id').size().reset_index()
df = df[df['id'].isin(nt[nt[0] >= 10].id.unique())]

# %%
df.head()
# Out:
#    entity     id      start  Unnamed: 0           team  pos  \
# 0       0  mushi 2012-09-08           0  orangeesports    1
# 1       0  mushi 2012-10-22         216  orangeesports    2
# 2       0  mushi 2012-11-29         671  orangeesports    2
# 3       0  mushi 2014-05-24        4891             dk    2
# 4       0  mushi 2015-01-05        6679       lvgaming    5
#
#                             tour    prizepool place  prizeusd     ...      \
# 0    WCG Asian Championship 2012  6000.000000    1       3000     ...
# 1  G-1 Champions League Season 4 52879.200000    3       8012     ...
# 2         World Cyber Games 2012 33000.000000     4         0     ...
# 3      MarsTV Dota 2 League 2014 24046.500000  3-4     160310     ...
# 4         Dota 2 League Season 5 58397.000000    1      26679     ...
#
#    exp       cog           name        dob       age  season   tiprize  \
# 0    0  Malaysia  Chai Yee Fung 1990-11-27 21.782341     ti3 14.871348
# 1    1  Malaysia  Chai Yee Fung 1990-11-27 21.902806     ti3 14.871348
# 2    2  Malaysia  Chai Yee Fung 1990-11-27 22.006845     ti3 14.871348
# 3   21  Malaysia  Chai Yee Fung 1990-11-27 23.488022     ti4 16.206471
# 4   29  Malaysia  Chai Yee Fung 1990-11-27 24.106776     ti5 16.729469
#
#      wdiffr    cumuwr        perf
# 0 -1.214596 -1.214596 1445.816755
# 1 47.650947 46.436351 1493.467703
# 2 -1.442597 44.993754 1492.025105
# 3  7.779183 52.772936 1499.804288
# 4 -1.633441 51.139496 1498.170847
#
# [5 rows x 32 columns]

# %%
def panelOLSResult(df, Y, X):
    from linearmodels import PanelOLS 
    panel_data = df.set_index(['entity', 'start']).sort_index()
    panel_data['agesq'] = panel_data.age ** 2
    panel_data['const'] = 1
    panel_data['lexp'] = (panel_data['exp'] + 1).apply(np.log)
    Y = panel_data[Y]
    X = panel_data[X]
    mod = PanelOLS(Y, X, entity_effects=True)
    return mod.fit()

def feResult(res):
    fe = res.estimated_effects.reset_index().drop_duplicates().drop_duplicates(subset=['entity']).drop('time', 1)
    return ent.merge(fe, on='entity').sort_values('estimated_effects', ascending=False)

# %% [markdown]
# ### Age and experience

# %%
from linearmodels import PanelOLS 
panel_data = df[['entity', 'start', 'perf', 'age', 'exp', 'pos']].set_index(['entity', 'start']).sort_index()
panel_data['agesq'] = panel_data.age ** 2
panel_data['const'] = 1
panel_data['lexp'] = (panel_data['exp'] + 1).apply(np.log)

# %%
len(df.entity.unique())
# Out:
# 164

# %%
df.head()
# Out:
#    entity     id      start  Unnamed: 0           team  pos  \
# 0       0  mushi 2012-09-08           0  orangeesports    1
# 1       0  mushi 2012-10-22         216  orangeesports    2
# 2       0  mushi 2012-11-29         671  orangeesports    2
# 3       0  mushi 2014-05-24        4891             dk    2
# 4       0  mushi 2015-01-05        6679       lvgaming    5
#
#                             tour    prizepool place  prizeusd     ...      \
# 0    WCG Asian Championship 2012  6000.000000    1       3000     ...
# 1  G-1 Champions League Season 4 52879.200000    3       8012     ...
# 2         World Cyber Games 2012 33000.000000     4         0     ...
# 3      MarsTV Dota 2 League 2014 24046.500000  3-4     160310     ...
# 4         Dota 2 League Season 5 58397.000000    1      26679     ...
#
#    exp       cog           name        dob       age  season   tiprize  \
# 0    0  Malaysia  Chai Yee Fung 1990-11-27 21.782341     ti3 14.871348
# 1    1  Malaysia  Chai Yee Fung 1990-11-27 21.902806     ti3 14.871348
# 2    2  Malaysia  Chai Yee Fung 1990-11-27 22.006845     ti3 14.871348
# 3   21  Malaysia  Chai Yee Fung 1990-11-27 23.488022     ti4 16.206471
# 4   29  Malaysia  Chai Yee Fung 1990-11-27 24.106776     ti5 16.729469
#
#      wdiffr    cumuwr        perf
# 0 -1.214596 -1.214596 1445.816755
# 1 47.650947 46.436351 1493.467703
# 2 -1.442597 44.993754 1492.025105
# 3  7.779183 52.772936 1499.804288
# 4 -1.633441 51.139496 1498.170847
#
# [5 rows x 32 columns]

# %%
df.describe()
# Out:
#            entity   Unnamed: 0         pos       prizepool  \
# count 4861.000000  4861.000000 4861.000000     4861.000000
# mean    89.689570  6918.633203    2.996091  1342571.963859
# std     61.968073  3386.208016    1.415299  4296199.481134
# min      0.000000     0.000000    1.000000     4410.000000
# 25%     35.000000  4248.000000    2.000000    39000.000000
# 50%     81.000000  7312.000000    3.000000   100000.000000
# 75%    134.000000  9622.000000    4.000000   277668.000000
# max    232.000000 12374.000000    5.000000 24787916.000000
#
#                  prizeusd  startglicko2mu  startglicko2phi  \
# count         4861.000000     4861.000000      4861.000000
# mean     264136105.668792     1841.128250        42.634076
# std     3622600182.947815       97.213157         6.576886
# min              0.000000     1542.725781        28.869240
# 25%           1500.000000     1778.144576        38.363352
# 50%          14000.000000     1847.199041        41.489108
# 75%          96860.000000     1913.222326        44.995443
# max   102512933715.000000     2070.341655        69.914737
#
#        startglicko2rating  endglicko2mu  endglicko2phi     ...      \
# count         4861.000000   4861.000000    4861.000000     ...
# mean          1734.543059   1845.487274      41.275249     ...
# std            102.479247     95.447060       5.895585     ...
# min           1377.868237   1514.769232      27.318820     ...
# 25%           1663.140303   1780.646087      37.368550     ...
# 50%           1742.696820   1849.448321      40.319949     ...
# 75%           1811.580851   1915.028650      43.742622     ...
# max           1952.785682   2089.277451      68.869853     ...
#
#             cumur        init  normalRating  teamrating         exp  \
# count 4861.000000 4861.000000   4861.000000 4861.000000 4861.000000
# mean   271.002323 1598.728616   1869.730939 1856.011608   26.041761
# std    266.747862   94.677296    252.564205  186.150147   17.359077
# min   -482.341083 1377.868237   1120.965747 1321.284974    0.000000
# 25%     61.783916 1540.350904   1698.604900 1721.643107   12.000000
# 50%    234.288187 1603.306830   1841.067619 1847.128391   22.000000
# 75%    429.964957 1645.784093   2005.501781 1983.505873   37.000000
# max   1170.654012 1898.778787   2698.966417 2411.544440   83.000000
#
#               age     tiprize      wdiffr      cumuwr        perf
# count 4861.000000 4861.000000 4861.000000 4861.000000 4861.000000
# mean    22.639532   16.463026    5.124528  174.901909 1773.630525
# std      2.498968    0.683499   25.210886  176.125550  171.782185
# min     15.739904   14.871348 -181.977433 -268.931932 1334.374897
# 25%     20.941821   16.206471   -5.364576   37.988052 1654.939317
# 50%     22.696783   16.729469   -1.967027  148.379382 1752.318285
# 75%     24.399726   16.849042   12.563774  286.714991 1878.260351
# max     29.333333   17.025867  153.087427  653.655179 2275.313145
#
# [8 rows x 22 columns]

# %%
panel_data.describe()
# Out:
#              perf         age         exp         pos       agesq       const  \
# count 4861.000000 4861.000000 4861.000000 4861.000000 4861.000000 4861.000000
# mean  1773.630525   22.639532   26.041761    2.996091  518.791967    1.000000
# std    171.782185    2.498968   17.359077    1.415299  112.871091    0.000000
# min   1334.374897   15.739904    0.000000    1.000000  247.744583    1.000000
# 25%   1654.939317   20.941821   12.000000    2.000000  438.559853    1.000000
# 50%   1752.318285   22.696783   22.000000    3.000000  515.143960    1.000000
# 75%   1878.260351   24.399726   37.000000    4.000000  595.346639    1.000000
# max   2275.313145   29.333333   83.000000    5.000000  860.444444    1.000000
#
#              lexp
# count 4861.000000
# mean     3.041507
# std      0.798491
# min      0.000000
# 25%      2.564949
# 50%      3.135494
# 75%      3.637586
# max      4.430817

# %%
Y = panel_data['perf']
X = panel_data[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.2927
# Estimator:                   PanelOLS   R-squared (Between):              0.9941
# No. Observations:                4861   R-squared (Within):               0.2927
# Date:                Tue, May 01 2018   R-squared (Overall):              0.9916
# Time:                        12:04:27   Log-likelihood                -2.829e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      647.40
# Entities:                         164   P-value                           0.0000
# Avg Obs:                       29.640   Distribution:                  F(3,4694)
# Min Obs:                      10.0000
# Max Obs:                       76.000   F-statistic (robust):             647.40
#                                         P-value                           0.0000
# Time periods:                     213   Distribution:                  F(3,4694)
# Avg Obs:                       22.822
# Min Obs:                       1.0000
# Max Obs:                       73.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            129.92     13.881     9.3600     0.0000      102.71      157.14
# agesq         -2.7105     0.2872    -9.4371     0.0000     -3.2736     -2.1474
# lexp           69.477     3.5042     19.827     0.0000      62.607      76.347
# ==============================================================================
#
# F-test for Poolability: 67.877
# P-value: 0.0000
# Distribution: F(163,4694)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
core = panel_data[panel_data['pos'] <= 3]
core.describe()
# Out:
#              perf         age         exp         pos       agesq       const  \
# count 2914.000000 2914.000000 2914.000000 2914.000000 2914.000000 2914.000000
# mean  1776.474325   22.496290   25.924159    1.994852  512.184704    1.000000
# std    169.411326    2.470570   17.350907    0.819209  110.687884    0.000000
# min   1402.735726   15.739904    0.000000    1.000000  247.744583    1.000000
# 25%   1660.026224   20.909651   12.000000    1.000000  437.213503    1.000000
# 50%   1756.791830   22.607803   22.000000    2.000000  511.112753    1.000000
# 75%   1879.044273   24.209446   37.000000    3.000000  586.097261    1.000000
# max   2275.313145   29.333333   83.000000    3.000000  860.444444    1.000000
#
#              lexp
# count 2914.000000
# mean     3.029324
# std      0.816306
# min      0.000000
# 25%      2.564949
# 50%      3.135494
# 75%      3.637586
# max      4.430817

# %%
Y = core['perf']
X = core[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.3055
# Estimator:                   PanelOLS   R-squared (Between):              0.9750
# No. Observations:                2914   R-squared (Within):               0.3055
# Date:                Tue, May 01 2018   R-squared (Overall):              0.9697
# Time:                        12:11:42   Log-likelihood                -1.691e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      407.20
# Entities:                         164   P-value                           0.0000
# Avg Obs:                       17.768   Distribution:                  F(3,2777)
# Min Obs:                       0.0000
# Max Obs:                       68.000   F-statistic (robust):             407.20
#                                         P-value                           0.0000
# Time periods:                     213   Distribution:                  F(3,2777)
# Avg Obs:                       13.681
# Min Obs:                       1.0000
# Max Obs:                       45.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            102.36     18.910     5.4131     0.0000      65.283      139.44
# agesq         -1.9066     0.3906    -4.8811     0.0000     -2.6725     -1.1407
# lexp           61.396     4.5548     13.479     0.0000      52.465      70.328
# ==============================================================================
#
# F-test for Poolability: 47.712
# P-value: 0.0000
# Distribution: F(133,2777)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
sup = panel_data[panel_data['pos'] >= 4]
sup.describe()
# Out:
#              perf         age         exp         pos       agesq       const  \
# count 1947.000000 1947.000000 1947.000000 1947.000000 1947.000000 1947.000000
# mean  1769.374319   22.853916   26.217771    4.494607  528.680803    1.000000
# std    175.228242    2.526379   17.374268    0.500099  115.385559    0.000000
# min   1334.374897   16.501027    0.000000    4.000000  272.283882    1.000000
# 25%   1647.208215   21.029432   13.000000    4.000000  442.237013    1.000000
# 50%   1746.206170   22.822724   22.000000    4.000000  520.876738    1.000000
# 75%   1877.231603   24.854209   37.000000    5.000000  617.731727    1.000000
# max   2221.051488   28.670773   79.000000    5.000000  822.013250    1.000000
#
#              lexp
# count 1947.000000
# mean     3.059741
# std      0.770906
# min      0.000000
# 25%      2.639057
# 50%      3.135494
# 75%      3.637586
# max      4.382027

# %%
Y = sup['perf']
X = sup[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.2645
# Estimator:                   PanelOLS   R-squared (Between):              0.9860
# No. Observations:                1947   R-squared (Within):               0.2645
# Date:                Tue, May 01 2018   R-squared (Overall):              0.9878
# Time:                        12:12:12   Log-likelihood                -1.125e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      220.96
# Entities:                         162   P-value                           0.0000
# Avg Obs:                       12.019   Distribution:                  F(3,1843)
# Min Obs:                       0.0000
# Max Obs:                       73.000   F-statistic (robust):             220.96
#                                         P-value                           0.0000
# Time periods:                     213   Distribution:                  F(3,1843)
# Avg Obs:                       9.1408
# Min Obs:                       0.0000
# Max Obs:                       29.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            155.23     21.019     7.3852     0.0000      114.00      196.45
# agesq         -3.6383     0.4335    -8.3937     0.0000     -4.4884     -2.7882
# lexp           85.621     5.7942     14.777     0.0000      74.257      96.985
# ==============================================================================
#
# F-test for Poolability: 53.599
# P-value: 0.0000
# Distribution: F(100,1843)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
pos1 = panel_data[panel_data['pos'] == 1]
pos1.describe()
# Out:
#              perf        age        exp        pos      agesq      const  \
# count  985.000000 985.000000 985.000000 985.000000 985.000000 985.000000
# mean  1787.122207  22.629829  28.490355   1.000000 518.735037   1.000000
# std    184.816114   2.575382  17.603762   0.000000 118.550085   0.000000
# min   1402.735726  16.720055   0.000000   1.000000 279.560231   1.000000
# 25%   1657.205091  20.908966  14.000000   1.000000 437.184878   1.000000
# 50%   1769.178419  22.554415  26.000000   1.000000 508.701626   1.000000
# 75%   1896.806525  24.169747  41.000000   1.000000 584.176658   1.000000
# max   2275.313145  29.333333  83.000000   1.000000 860.444444   1.000000
#
#             lexp
# count 985.000000
# mean    3.149038
# std     0.773032
# min     0.000000
# 25%     2.708050
# 50%     3.295837
# 75%     3.737670
# max     4.430817

# %%
Y = pos1['perf']
X = pos1[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.3604
# Estimator:                   PanelOLS   R-squared (Between):             -0.1574
# No. Observations:                 985   R-squared (Within):               0.3604
# Date:                Tue, May 01 2018   R-squared (Overall):             -0.0086
# Time:                        12:04:28   Log-likelihood                   -5651.7
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      170.20
# Entities:                         160   P-value                           0.0000
# Avg Obs:                       6.1562   Distribution:                   F(3,906)
# Min Obs:                       0.0000
# Max Obs:                       65.000   F-statistic (robust):             170.20
#                                         P-value                           0.0000
# Time periods:                     213   Distribution:                   F(3,906)
# Avg Obs:                       4.6244
# Min Obs:                       0.0000
# Max Obs:                       16.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            276.67     27.952     9.8980     0.0000      221.82      331.53
# agesq         -5.4795     0.5766    -9.5026     0.0000     -6.6112     -4.3478
# lexp           51.434     8.0602     6.3813     0.0000      35.615      67.253
# ==============================================================================
#
# F-test for Poolability: 42.170
# P-value: 0.0000
# Distribution: F(75,906)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
pos2 = panel_data[panel_data['pos'] == 2]
pos2.describe()
# Out:
#              perf        age        exp        pos      agesq      const  \
# count  959.000000 959.000000 959.000000 959.000000 959.000000 959.000000
# mean  1779.845049  21.583329  24.088634   2.000000 471.405250   1.000000
# std    160.955792   2.360294  17.653752   0.000000 101.050674   0.000000
# min   1404.395915  15.739904   0.000000   2.000000 247.744583   1.000000
# 25%   1684.418430  20.071184  10.500000   2.000000 402.852462   1.000000
# 50%   1760.927044  21.650924  20.000000   2.000000 468.762511   1.000000
# 75%   1880.951983  23.333333  34.000000   2.000000 544.444446   1.000000
# max   2223.749856  27.709788  71.000000   2.000000 767.832341   1.000000
#
#             lexp
# count 959.000000
# mean    2.918821
# std     0.873253
# min     0.000000
# 25%     2.441401
# 50%     3.044522
# 75%     3.555348
# max     4.276666

# %%
Y = pos2['perf']
X = pos2[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.3380
# Estimator:                   PanelOLS   R-squared (Between):              0.9655
# No. Observations:                 959   R-squared (Within):               0.3380
# Date:                Tue, May 01 2018   R-squared (Overall):              0.9732
# Time:                        12:09:31   Log-likelihood                   -5506.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      149.93
# Entities:                         163   P-value                           0.0000
# Avg Obs:                       5.8834   Distribution:                   F(3,881)
# Min Obs:                       0.0000
# Max Obs:                       66.000   F-statistic (robust):             149.93
#                                         P-value                           0.0000
# Time periods:                     213   Distribution:                   F(3,881)
# Avg Obs:                       4.5023
# Min Obs:                       0.0000
# Max Obs:                       16.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            142.21     39.456     3.6043     0.0003      64.773      219.65
# agesq         -2.5143     0.8296    -3.0308     0.0025     -4.1425     -0.8861
# lexp           45.473     7.8700     5.7780     0.0000      30.026      60.919
# ==============================================================================
#
# F-test for Poolability: 25.268
# P-value: 0.0000
# Distribution: F(74,881)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
pos3 = panel_data[panel_data['pos'] == 3]
pos3.describe()
# Out:
#              perf        age        exp        pos      agesq      const  \
# count  970.000000 970.000000 970.000000 970.000000 970.000000 970.000000
# mean  1762.329285  23.263295  25.132990   3.000000 545.850085   1.000000
# std    160.165858   2.161944  16.479209   0.000000  98.185233   0.000000
# min   1417.604740  16.331280   0.000000   3.000000 266.710705   1.000000
# 25%   1645.347321  21.954825  12.000000   3.000000 482.014361   1.000000
# 50%   1737.169771  23.575633  22.000000   3.000000 555.810477   1.000000
# 75%   1859.531417  24.699521  36.000000   3.000000 610.066382   1.000000
# max   2188.676391  27.860370  79.000000   3.000000 776.200195   1.000000
#
#             lexp
# count 970.000000
# mean    3.017011
# std     0.784631
# min     0.000000
# 25%     2.564949
# 50%     3.135494
# 75%     3.610918
# max     4.382027

# %%
Y = pos3['perf']
X = pos3[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.3283
# Estimator:                   PanelOLS   R-squared (Between):             -3.6411
# No. Observations:                 970   R-squared (Within):               0.3283
# Date:                Tue, May 01 2018   R-squared (Overall):             -3.4268
# Time:                        12:04:29   Log-likelihood                   -5582.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      145.47
# Entities:                         164   P-value                           0.0000
# Avg Obs:                       5.9146   Distribution:                   F(3,893)
# Min Obs:                       0.0000
# Max Obs:                       67.000   F-statistic (robust):             145.47
#                                         P-value                           0.0000
# Time periods:                     213   Distribution:                   F(3,893)
# Avg Obs:                       4.5540
# Min Obs:                       0.0000
# Max Obs:                       15.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age           -191.79     46.679    -4.1086     0.0000     -283.40     -100.17
# agesq          4.1177     0.9474     4.3464     0.0000      2.2584      5.9770
# lexp           84.734     8.3494     10.149     0.0000      68.347      101.12
# ==============================================================================
#
# F-test for Poolability: 27.599
# P-value: 0.0000
# Distribution: F(73,893)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
pos4 = panel_data[panel_data['pos'] == 4]
pos4.describe()
# Out:
#              perf        age        exp        pos      agesq      const  \
# count  984.000000 984.000000 984.000000 984.000000 984.000000 984.000000
# mean  1752.360082  22.580755  24.959350   4.000000 516.605199   1.000000
# std    174.920537   2.592588  16.263859   0.000000 116.743005   0.000000
# min   1334.374897  16.501027   0.000000   4.000000 272.283882   1.000000
# 25%   1639.305112  20.598220  13.000000   4.000000 424.286689   1.000000
# 50%   1729.947661  22.666667  21.000000   4.000000 513.777785   1.000000
# 75%   1855.172196  24.783710  34.000000   4.000000 614.232272   1.000000
# max   2221.051488  28.670773  74.000000   4.000000 822.013250   1.000000
#
#             lexp
# count 984.000000
# mean    3.023703
# std     0.754162
# min     0.000000
# 25%     2.639057
# 50%     3.091042
# 75%     3.555348
# max     4.317488

# %%
Y = pos4['perf']
X = pos4[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.2379
# Estimator:                   PanelOLS   R-squared (Between):              0.9219
# No. Observations:                 984   R-squared (Within):               0.2379
# Date:                Tue, May 01 2018   R-squared (Overall):              0.9299
# Time:                        12:04:30   Log-likelihood                   -5589.8
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      92.818
# Entities:                         162   P-value                           0.0000
# Avg Obs:                       6.0741   Distribution:                   F(3,892)
# Min Obs:                       0.0000
# Max Obs:                       52.000   F-statistic (robust):             92.818
#                                         P-value                           0.0000
# Time periods:                     213   Distribution:                   F(3,892)
# Avg Obs:                       4.6197
# Min Obs:                       0.0000
# Max Obs:                       14.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            185.49     27.314     6.7911     0.0000      131.89      239.10
# agesq         -4.2801     0.5689    -7.5231     0.0000     -5.3967     -3.1635
# lexp           69.619     8.0032     8.6988     0.0000      53.911      85.326
# ==============================================================================
#
# F-test for Poolability: 38.169
# P-value: 0.0000
# Distribution: F(88,892)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()

# %%
pos5 = panel_data[panel_data['pos'] == 5]
pos5.describe()
# Out:
#              perf        age        exp        pos      agesq      const  \
# count  963.000000 963.000000 963.000000 963.000000 963.000000 963.000000
# mean  1786.759583  23.133034  27.503634   5.000000 541.019737   1.000000
# std    173.920335   2.426643  18.359506   0.000000 112.712572   0.000000
# min   1339.237768  17.234771   0.000000   5.000000 297.037321   1.000000
# 25%   1658.974883  21.357974  13.000000   5.000000 456.163053   1.000000
# 50%   1762.730107  23.082820  23.000000   5.000000 532.816579   1.000000
# 75%   1897.370469  24.970568  39.000000   5.000000 623.529273   1.000000
# max   2197.749410  28.629706  79.000000   5.000000 819.660047   1.000000
#
#             lexp
# count 963.000000
# mean    3.096566
# std     0.786334
# min     0.000000
# 25%     2.639057
# 50%     3.178054
# 75%     3.688879
# max     4.382027

# %%
Y = pos5['perf']
X = pos5[['age', 'agesq', 'lexp']]
mod = PanelOLS(Y, X, entity_effects=True)
res = mod.fit()
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                   perf   R-squared:                        0.3029
# Estimator:                   PanelOLS   R-squared (Between):              0.9905
# No. Observations:                 963   R-squared (Within):               0.3029
# Date:                Tue, May 01 2018   R-squared (Overall):              0.9850
# Time:                        12:04:31   Log-likelihood                   -5544.6
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      127.58
# Entities:                         162   P-value                           0.0000
# Avg Obs:                       5.9444   Distribution:                   F(3,881)
# Min Obs:                       0.0000
# Max Obs:                       53.000   F-statistic (robust):             127.58
#                                         P-value                           0.0000
# Time periods:                     213   Distribution:                   F(3,881)
# Avg Obs:                       4.5211
# Min Obs:                       0.0000
# Max Obs:                       15.000
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# age            134.34     32.776     4.0989     0.0000      70.017      198.67
# agesq         -3.3729     0.6771    -4.9811     0.0000     -4.7020     -2.0439
# lexp           111.36     8.5395     13.040     0.0000      94.598      128.12
# ==============================================================================
#
# F-test for Poolability: 30.937
# P-value: 0.0000
# Distribution: F(78,881)
#
# Included effects: Entity
# """

# %%
# create 1000 equally spaced points between -10 and 10
agex = np.linspace(15, 30, 1000)
lexpx = np.linspace(1, 70, 1000)
# calculate the y value for each element of the x vector
age = res.params.agesq*agex**2 + res.params.age*agex 
lexp = res.params.lexp*np.log(lexpx)

fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(agex, age)
ax[0].set_title("Peak age is: " + str(-res.params.age / (2 * res.params.agesq)))
ax[1].plot(lexpx, lexp)
ax[1].set_title("Partial effect of lexp")
plt.show()
