# %%
# %matplotlib inline
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('glicko.csv', encoding = "ISO-8859-1")
dob = pd.read_csv('idanddob.csv', encoding = "ISO-8859-1")

# %%
dob = dob.drop(['id'], axis=1).rename(columns={'idlow': 'id'})

# %%
df = df.merge(dob, how='left', on=['id'])

# %%
df = df.dropna().drop_duplicates(['id', 'tour'])

# %%
df.head()
# Out:
#              team position      id                             tour prizeusd  \
# 0   orangeesports     pos1   mushi      WCG Asian Championship 2012     6000
# 1   orangeesports     pos2    kyxy      WCG Asian Championship 2012     6000
# 3   orangeesports     pos4  xtinct      WCG Asian Championship 2012     6000
# 4   orangeesports     pos5  winter      WCG Asian Championship 2012     6000
# 40   evilgeniuses     pos1    fear  RaidCall Dota 2 League Season 1    10000
#
#          start         end     startelo  startglicko2mu  startglicko2phi  \
# 0   08/09/2012  09/09/2012  1029.765307     1609.568030        65.014671
# 1   08/09/2012  09/09/2012  1029.765307     1609.568030        65.014671
# 3   08/09/2012  09/09/2012  1029.765307     1609.568030        65.014671
# 4   08/09/2012  09/09/2012  1029.765307     1609.568030        65.014671
# 40  10/09/2012  18/11/2012  1127.178191     1739.804399        58.251412
#
#     startglicko2rating       endelo  endglicko2mu  endglicko2phi  \
# 0          1447.031352  1028.365630    1609.56803      65.845186
# 1          1447.031352  1028.365630    1609.56803      65.845186
# 3          1447.031352  1028.365630    1609.56803      65.845186
# 4          1447.031352  1028.365630    1609.56803      65.845186
# 40         1594.175869  1130.694281    1760.59337      42.668357
#
#     endglicko2rating            cog                  name         dob
# 0        1444.955065       Malaysia         Chai Yee Fung  1990-11-27
# 1        1444.955065       Malaysia         Lee Kong Yang  1991-05-26
# 3        1444.955065       Malaysia  Joel Chan Zhan Leong  1988-10-16
# 4        1444.955065       Malaysia        Chan Litt Binn  1989-08-21
# 40       1653.922476  United States        Clinton Loomis  1988-02-19

# %%
df.position = pd.to_numeric(df.position.str[-1])

# %%
df = df.rename(columns={'cog': 'country','id': 'player','prizeusd': 'prize','startelo': 'startelo64','endelo': 'endelo64'}).reset_index()

# %%
df = df[['country','team','player','position','dob','tour','start','end','prize','startelo64','endelo64']]

# %%
#convert day to datetime type
df.start = pd.to_datetime(df.start, format='%d/%m/%Y')
df.end = pd.to_datetime(df.end, format='%d/%m/%Y')
df.dob = pd.to_datetime(df.dob)
df.dtypes

#elo gain from each tournament
df['delo'] = df.endelo64 - df.startelo64

#cumulative sum of delo
cumsums = df[['player', 'start', 'delo']].groupby(['player', 'start']).sum().groupby(level=0).cumsum()
df = df.set_index(['player', 'start'])
df['rating'] = cumsums
df = df.reset_index()

#calculate age in year
df['age'] = (df.start - df.dob) / pd.Timedelta(days=365.25)

#experience
for player in df.player.unique():
    try:
        dfid = pd.DataFrame(df[df['player'] == player].sort_values('start').tour.unique()).reset_index().rename(columns={'index': 'exp', 0: 'tour'})
        dfid['player'] = player
        dfid2 = pd.concat([dfid2, dfid])
    except NameError:
        dfid2 = dfid
        continue

df = pd.merge(df, dfid2, how='left', on=['player', 'tour'])

#init is rating + initial mmr (assume first team = player's calibration)
init = df[df['startelo64'].notnull()].sort_values('start')[['startelo64', 'player']].groupby('player').first().reset_index().rename(columns={'startelo64': 'init'})
df = pd.merge(df, init, how='left', on='player')
df.init = df.rating + df.init

# %%
df = df.drop_duplicates(['player', 'tour'])

# %%
df.sample(5)
# Out:
#           player      start        country            team  position  \
# 2710        kaka 2015-05-09          China  hypergloryteam         4
# 4002  oldchicken 2016-06-30          China           ehome         2
# 1902         hao 2014-09-12          China          newbee         1
# 1424       demon 2014-04-01  United States      teamliquid         1
# 2480       super 2015-03-09          China      vicigaming         2
#
#             dob                             tour        end    prize  \
# 2710 1992-11-07                    G-League 2015 2015-07-10    43497
# 4002 1993-05-26                    G-League 2016 2016-07-09  58359.6
# 1902 1990-07-28                  ECL 2014 Autumn 2014-12-30    20930
# 1424 1990-07-08     HyperX D2L Western Challenge 2014-06-24    68517
# 2480 1993-01-04  StarLadder StarSeries Season 12 2015-04-26   150000
#
#        startelo64     endelo64        delo      rating        age  exp  \
# 2710  1132.171264   984.821722 -147.349542  151.390710  22.499658   14
# 4002  1220.278425  1271.158665   50.880240  448.388421  23.096509    9
# 1902  1280.590063  1304.308365   23.718302  736.990686  24.125941   16
# 1424  1186.067156  1129.691798  -56.375358  100.958922  23.731691   18
# 2480  1257.719285  1466.356754  208.637470  465.930674  22.173854   31
#
#              init
# 2710  1249.072193
# 4002  1783.365023
# 1902  2006.565916
# 1424  1228.137113
# 2480  1674.284221

# %%
x = df['age']
y = df['init']
plt.scatter(x, y, alpha = 0.5)
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 2))(np.unique(x)), 'r')

# %%
player = 'dendi'
fig = plt.figure(figsize=(10, 6))
ax = fig.gca()
df[df['player'] == player][['init', 'age']].set_index('age').sort_index().plot(ax=ax)
df[df['player'] == player][['init', 'tour', 'age', 'team', 'start']].set_index('age').sort_index()
# Out:
#                   init                                              tour  \
# age
# 22.715948  1304.880917                    StarLadder StarSeries Season 3
# 22.757016  1443.056727                    GosuLeague Season 4 Division 1
# 22.841889  1423.148063                  Electronic Sports World Cup 2012
# 22.858316  1479.616448                    GosuLeague Season 5 Division 1
# 22.872005  1536.084833                    StarLadder StarSeries Season 4
# 22.896646  1528.867724                             DreamHack Winter 2012
# 22.907598  1537.275586                              The Defense Season 3
# 22.951403  1481.744928                   RaidCall Dota 2 League Season 2
# 22.954141  1576.599456                             ASUS Open 2012 Finals
# 23.118412  1467.806662                    StarLadder StarSeries Season 5
# 23.189596  1691.583681                      WePlay Dota2 League Season 1
# 23.214237  1850.453988                    RaidCall EMS One Spring Season
# 23.227926  1842.465878                        Techlabs Cup 2013 Season 1
# 23.342916  1765.619410                         Curse Dota 2 Invitational
# 23.383984  1892.507832                    StarLadder StarSeries Season 6
# 23.386721  2147.329173                   RaidCall Dota 2 League Season 3
# 23.389459  2398.020251                              The Defense Season 4
# 23.457906  2378.229318                             DreamHack Summer 2013
# 23.460643  2299.287860                                     Alienware Cup
# 23.589322  2286.684770                            The International 2013
