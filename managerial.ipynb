# %%
# %matplotlib inline
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd
pd.set_option('float_format', '{:f}'.format)

# visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("managerial.csv")

# %%
df
# Out:
#     effect ranking  facebook ranking                 team       facebook  \
# 0                1                34             faceless   69140.000000
# 1                2                40           teamspirit    9004.000000
# 2                3                35              mvphot6   25044.000000
# 3                4                19                   og  130620.000000
# 4                5                25        orangeesports  227856.000000
# 5                6                23                ehome   29985.000000
# 6                7                38          teamadfinem   43528.000000
# 7                8                21           tncproteam  397134.000000
# 8                9                36           mvpphoenix   25044.000000
# 9               10                43            cdecyouth    2973.000000
# 10              11                30         vegasquadron  106739.000000
# 11              12                 4         natusvincere 1818956.000000
# ...

# %%
df.describe()
# Out:
#        effect ranking  facebook ranking       facebook        twitter  \
# count       58.000000         58.000000      51.000000      46.000000
# mean        29.500000         29.500000  311518.137255  146507.695652
# std         16.886879         16.886879  509675.538710  226260.756265
# min          1.000000          1.000000     191.000000      15.000000
# 25%         15.250000         15.250000   25044.000000   11325.000000
# 50%         29.500000         29.500000  101427.000000   45500.000000
# 75%         43.750000         43.750000  398199.500000  207000.000000
# max         58.000000         58.000000 2619366.000000 1150000.000000
#
#                   qq          weibo            vk        highest  \
# count      13.000000      12.000000     10.000000      54.000000
# mean   332252.000000  905351.500000 115889.800000  485338.222222
# std    462175.006676  857127.564015 172006.891773  670034.712673
# min      4079.000000   16495.000000      4.000000     191.000000
# ...

# %%
from scipy import stats

# %%
stats.spearmanr(df['facebook ranking'], df['effect ranking'])
# Out:
# SpearmanrResult(correlation=0.078224491679227293, pvalue=0.55944438940465036)

# %%
df = df.dropna(subset=['facebook'])

# %%
stats.spearmanr(df['estimated effect'], df['facebook'])
# Out:
# SpearmanrResult(correlation=-0.095761773427670213, pvalue=0.50383965384518814)

# %%
plt.scatter(df['facebook ranking'], df['effect ranking'])
plt.ylabel('managerial ranking')
plt.xlabel('social media ranking')
# Out:
# Text(0.5,0,'social media ranking')
